# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd0
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 5
#       3 from folium.plugins import HeatMap, MarkerCluster
#       4 import pandas as pd0
# ----> 5 import src.py
#
# ModuleNotFoundError: No module named 'src.py'

# %%
df_sf = pd.read_csv("dataframes/df_sanfrancisco.csv")
df_sf
# Out:
#                                    name   latitude   longitude
# 0                                  Digg  37.764726 -122.394523  \
# 1                                   Wix  37.756720 -122.405070
# 2                             99designs  37.795531 -122.400598
# 3                                Minted  37.797435 -122.403175
# 4                           Netbiscuits  37.755037 -122.426442
# 5   Oakland International Airport (OAK)  37.712395 -122.213323
# 6                  Imane's Wonderschool  37.780740 -122.407515
# 7         Jean Parker Elementary School  37.797687 -122.411024
# 8            Montgomery St BART Station  37.788862 -122.402116
# 9                                Monroe  37.797885 -122.405014
# 10          Enjoy Vegetarian Restaurant  37.795836 -122.405323
# 11        Alice Marble Basketball Court  37.801449 -122.420352
# 12                            Starbucks  37.794601 -122.402669
# 13                         Bow Wow Meow  37.796647 -122.421645
#
#                             data  distance
# 0                 Design company       NaN
# 1                 Design company       NaN
# 2                 Design company       NaN
# 3                 Design company       NaN
# 4                 Design company       NaN
# 5                        Airport   19161.0
# 6                      Preschool    1834.0
# 7   Primary and Secondary School     693.0
# 8                  Train Station     888.0
# 9                    Night Clubs     210.0
# 10              Vegan Restaurant     203.0
# 11            Basketball Stadium    1580.0
# 12                     Starbucks     257.0
# 13                  Dog Grooming    1639.0

# %%
def creating_map(df, lat, lon, zoom=10):

    # Creating a map centered on the coordinates
    city_map = folium.Map(location=[lat, lon], zoom_start=zoom)
    
    data_dict={'Design company': ['pink','briefcase'],
               'Airport': ['blue', 'plane'], 
               'Preschool' : ['lightblue', 'baby-carriage'],
               'Primary and Secondary School': ['darkblue', 'graduation-cap'],
               'Train Station': ['darkred', 'train'],
               'Night Clubs': ['darkpurple', 'martini-glass'],
               'Vegan Restaurant': ['green', 'utensils'],
               'Basketball Stadium':['orange', 'basketball'],
               'Starbucks': ['cadetblue', 'mug-saucer'],
               'Dog Grooming': ['gray', 'dog']
              }
    for key, value in data_dict.items():
        data = df[df['data'] == key]
        # Iterating over the rows of the DataFrame
        for index, row in data.iterrows():
            name = row['name']
            latitude = row['latitude']
            longitude = row['longitude']

             # Creating a custom icon for the design company
            icon = folium.Icon(color=value[0], icon=value[1], prefix='fa')
    
            # Adding a marker to the map for each office
            folium.Marker([latitude, longitude], icon=icon, popup=name).add_to(city_map)

    icon = Icon (color = "red", icon_color = "white", icon = "star", prefix = "fa")
    city_location = Marker(location = [lat, lon], tooltip = "Location", icon = icon)
    city_location.add_to(city_map)

    return city_map

# %%
sf_map=creating_map(df_sf, "37.7968917", "-122.4032027", 14)
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_caa63f27a062f8c1e78b969ec3815aba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_caa63f27a062f8c1e78b969ec3815aba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_caa63f27a062f8c1e78b969ec3815aba = L.map(
#                 &quot;map_caa63f27a062f8c1e78b969ec3815aba&quot;,
#                 {
#                     center: [37.7968917, -122.4032027],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e5e14e440f3e5c42995a2425ce9179c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_caa63f27a062f8c1e78b969ec3815aba);
#
#
#             var marker_dc9650e7f2d8a387053ad8e573fd79b8 = L.marker(
#                 [37.764726, -122.394523],
#                 {}
#             ).addTo(map_caa63f27a062f8c1e78b969ec3815aba);
#
#
#             var icon_5d823733bd623a2e1e5f6abe5827f3ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_dc9650e7f2d8a387053ad8e573fd79b8.setIcon(icon_5d823733bd623a2e1e5f6abe5827f3ed);
#
#
#         var popup_172430f30e2bf7a8449b3bbb582fbdd0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce4f5ac727b386c2d3dc21fc9613fdc8 = $(`&lt;div id=&quot;html_ce4f5ac727b386c2d3dc21fc9613fdc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Digg&lt;/div&gt;`)[0];
#                 popup_172430f30e2bf7a8449b3bbb582fbdd0.setContent(html_ce4f5ac727b386c2d3dc21fc9613fdc8);
#
#
#
#         marker_dc9650e7f2d8a387053ad8e573fd79b8.bindPopup(popup_172430f30e2bf7a8449b3bbb582fbdd0)
#         ;
#
#
#
#
#             var marker_75c07e78ed8e6a803b830b708cc4a93e = L.marker(
#                 [37.75672, -122.40507],
#                 {}
#             ).addTo(map_caa63f27a062f8c1e78b969ec3815aba);
#
#
#             var icon_b6b45ec9c5f7f287dd2e223e73d0da32 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_75c07e78ed8e6a803b830b708cc4a93e.setIcon(icon_b6b45ec9c5f7f287dd2e223e73d0da32);
#
#
#         var popup_424adcc4791b64a9dcaae9673d2b9719 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13e93cb0ae81d6471b7a695f994d81c5 = $(`&lt;div id=&quot;html_13e93cb0ae81d6471b7a695f994d81c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wix&lt;/div&gt;`)[0];
#                 popup_424adcc4791b64a9dcaae9673d2b9719.setContent(html_13e93cb0ae81d6471b7a695f994d81c5);
#
#
#
#         marker_75c07e78ed8e6a803b830b708cc4a93e.bindPopup(popup_424adcc4791b64a9dcaae9673d2b9719)
#         ;
#
#
#
#
#             var marker_402ae5b925a54e5c00edf445f111bdd1 = L.marker(
#                 [37.7955307, -122.4005983],
#                 {}
#             ).addTo(map_caa63f27a062f8c1e78b969ec3815aba);
#
#
#             var icon_bdc4e12b1ef96838c5f795fced57dcd3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_402ae5b925a54e5c00edf445f111bdd1.setIcon(icon_bdc4e12b1ef96838c5f795fced57dcd3);
#
#
#         var popup_6298f39c4db80b78a912b99996b2b15d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d65663b4e35a07bcb31795bd0bf156cc = $(`&lt;div id=&quot;html_d65663b4e35a07bcb31795bd0bf156cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;99designs&lt;/div&gt;`)[0];
#                 popup_6298f39c4db80b78a912b99996b2b15d.setContent(html_d65663b4e35a07bcb31795bd0bf156cc);
#
#
#
#         marker_402ae5b925a54e5c00edf445f111bdd1.bindPopup(popup_6298f39c4db80b78a912b99996b2b15d)
#         ;
#
#
#
#
#             var marker_bcd87e677e1dae2cb1e279d3fe27e4a3 = L.marker(
#                 [37.797435, -122.403175],
#                 {}
#             ).addTo(map_caa63f27a062f8c1e78b969ec3815aba);
#
#
#             var icon_de25f1cd8ba16a93f6f6b754ed557961 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&q

# %%
df_lon = pd.read_csv("dataframes/df_london.csv")
df_lon
# Out:
#                                 name   latitude  longitude
# 0                        Netbiscuits  51.513248  -0.154738  \
# 1                          Moonfruit  51.519130  -0.110160
# 2          London City Airport (LCY)  51.504029   0.049552
# 3                Home Star Childcare  51.513242  -0.141109
# 4              Netley Primary School  51.527677  -0.140121
# 5                        Marble Arch  51.513632  -0.158366
# 6                          Annabel's  51.509132  -0.146903
# 7                       Plants by De  51.513315  -0.150040
# 8  Tabard Gardens - Basketball Court  51.514811  -0.174869
# 9                          Starbucks  51.514326  -0.152723
#
#                            data  distance
# 0                Design company       NaN
# 1                Design company       NaN
# 2                       Airport   14166.0
# 3                     Preschool     942.0
# 4  Primary and Secondary School    1910.0
# 5                 Train Station     248.0
# 6                   Night Clubs     701.0
# 7              Vegan Restaurant     316.0
# 8            Basketball Stadium    1397.0
# 9                     Starbucks     241.0

# %%
lon_map=creating_map(df_lon, '51.5134019','-0.1566624', 14) 
lon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9bb170e1812c3a6701bf33f5b320cf7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9bb170e1812c3a6701bf33f5b320cf7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9bb170e1812c3a6701bf33f5b320cf7 = L.map(
#                 &quot;map_b9bb170e1812c3a6701bf33f5b320cf7&quot;,
#                 {
#                     center: [51.5134019, -0.1566624],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f895ac86d6952d1c55b83e175076e25 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b9bb170e1812c3a6701bf33f5b320cf7);
#
#
#             var marker_1fd395d970fe40340f9cb502fa11d5b4 = L.marker(
#                 [51.513248, -0.1547377],
#                 {}
#             ).addTo(map_b9bb170e1812c3a6701bf33f5b320cf7);
#
#
#             var icon_5f0fa9ecf09653fd286c369a55e3e6d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1fd395d970fe40340f9cb502fa11d5b4.setIcon(icon_5f0fa9ecf09653fd286c369a55e3e6d0);
#
#
#         var popup_953a44bac0aa5f1c7026c36a74243d1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cdae143497779644440645a26edc47e7 = $(`&lt;div id=&quot;html_cdae143497779644440645a26edc47e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Netbiscuits&lt;/div&gt;`)[0];
#                 popup_953a44bac0aa5f1c7026c36a74243d1d.setContent(html_cdae143497779644440645a26edc47e7);
#
#
#
#         marker_1fd395d970fe40340f9cb502fa11d5b4.bindPopup(popup_953a44bac0aa5f1c7026c36a74243d1d)
#         ;
#
#
#
#
#             var marker_32fe00e35e7ef2cca0305c8cb1d06498 = L.marker(
#                 [51.51913, -0.11016],
#                 {}
#             ).addTo(map_b9bb170e1812c3a6701bf33f5b320cf7);
#
#
#             var icon_c7a721771b098f3e50f8ece89a74e9e7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_32fe00e35e7ef2cca0305c8cb1d06498.setIcon(icon_c7a721771b098f3e50f8ece89a74e9e7);
#
#
#         var popup_8cc5f782cf5ecf3bf497d64f3dc739c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_848337e6ebe4c1502306765d6d30adb5 = $(`&lt;div id=&quot;html_848337e6ebe4c1502306765d6d30adb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Moonfruit&lt;/div&gt;`)[0];
#                 popup_8cc5f782cf5ecf3bf497d64f3dc739c4.setContent(html_848337e6ebe4c1502306765d6d30adb5);
#
#
#
#         marker_32fe00e35e7ef2cca0305c8cb1d06498.bindPopup(popup_8cc5f782cf5ecf3bf497d64f3dc739c4)
#         ;
#
#
#
#
#             var marker_782f7b6e9985740b89c27388e911c99e = L.marker(
#                 [51.504029, 0.049552],
#                 {}
#             ).addTo(map_b9bb170e1812c3a6701bf33f5b320cf7);
#
#
#             var icon_fb6913af903a0d76e866ee7c1da3adc3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_782f7b6e9985740b89c27388e911c99e.setIcon(icon_fb6913af903a0d76e866ee7c1da3adc3);
#
#
#         var popup_9eda003a5f46a05ba7635d84faf3538b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f58b6bdf9db86a3e44cfbb63bbc566e = $(`&lt;div id=&quot;html_4f58b6bdf9db86a3e44cfbb63bbc566e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;London City Airport (LCY)&lt;/div&gt;`)[0];
#                 popup_9eda003a5f46a05ba7635d84faf3538b.setContent(html_4f58b6bdf9db86a3e44cfbb63bbc566e);
#
#
#
#         marker_782f7b6e9985740b89c27388e911c99e.bindPopup(popup_9eda003a5f46a05ba7635d84faf3538b)
#         ;
#
#
#
#
#             var marker_c33e75eab8a9d229fdb132f1196ba4a1 = L.marker(
#                 [51.513242, -0.141109],
#                 {}
#             ).addTo(map_b9bb170e1812c3a6701bf33f5b320cf7);
#
#
#             var icon_3e2737af49d66c3338b4f1a15eacd10c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;baby-carriage&quot;,

# %%
df_nyc = pd.read_csv("dataframes/df_newyork.csv")
df_nyc
# Out:
#                            name   latitude  longitude
# 0                   Gilt Groupe  40.747270 -73.980064  \
# 1                   Squarespace  40.720810 -74.000870
# 2                 Banyan Branch  40.695170 -73.932300
# 3                   Netbiscuits  40.695170 -73.932300
# 4       LaGuardia Airport (LGA)  40.774527 -73.871941
# 5           Metrokids Preschool  40.748664 -73.970435
# 6            Xavier High School  40.738023 -73.994868
# 7          MTA Subway - 23rd St  40.740187 -73.986656
# 8               Hidden Lane Bar  40.734657 -73.987662
# 9            24th St Vegan Cafe  40.738894 -73.980623
# 10  Basketball Gym At The Dylan  40.746752 -73.985298
# 11                    Starbucks  40.740519 -73.984355
# 12             Reme's Oggi Pets  40.756870 -73.964245
#
#                             data  distance
# 0                 Design company       NaN
# 1                 Design company       NaN
# 2                 Design company       NaN
# 3                 Design company       NaN
# 4                        Airport   10447.0
# 5                      Preschool    1563.0
# 6   Primary and Secondary School     841.0
# 7                  Train Station     122.0
# 8                    Night Clubs     623.0
# 9               Vegan Restaurant     356.0
# 10            Basketball Stadium     749.0
# 11                     Starbucks      91.0
# 12                  Dog Grooming    2569.0

# %%
nyc_map=creating_map(df_nyc,'40.7398872','-73.9850319', 14) 
nyc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8e3bd8d78501916c593623f8e401c41 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8e3bd8d78501916c593623f8e401c41&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8e3bd8d78501916c593623f8e401c41 = L.map(
#                 &quot;map_b8e3bd8d78501916c593623f8e401c41&quot;,
#                 {
#                     center: [40.7398872, -73.9850319],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2be1d30ff1b917717877e0461676f648 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b8e3bd8d78501916c593623f8e401c41);
#
#
#             var marker_a438d866da08861c7af41ae774f88451 = L.marker(
#                 [40.74727, -73.9800645],
#                 {}
#             ).addTo(map_b8e3bd8d78501916c593623f8e401c41);
#
#
#             var icon_681fe60e6a2b5bae68fc2642c7824e06 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a438d866da08861c7af41ae774f88451.setIcon(icon_681fe60e6a2b5bae68fc2642c7824e06);
#
#
#         var popup_56037ffb2a6895b340be8bb7f16fd4a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ccecc80b387948a2f96cf2f07b6e3fd = $(`&lt;div id=&quot;html_9ccecc80b387948a2f96cf2f07b6e3fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gilt Groupe&lt;/div&gt;`)[0];
#                 popup_56037ffb2a6895b340be8bb7f16fd4a8.setContent(html_9ccecc80b387948a2f96cf2f07b6e3fd);
#
#
#
#         marker_a438d866da08861c7af41ae774f88451.bindPopup(popup_56037ffb2a6895b340be8bb7f16fd4a8)
#         ;
#
#
#
#
#             var marker_28378ce4533bdf43c0f372a07495a3de = L.marker(
#                 [40.72081, -74.00087],
#                 {}
#             ).addTo(map_b8e3bd8d78501916c593623f8e401c41);
#
#
#             var icon_aae23a6fc846bef753bd8df522e16645 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_28378ce4533bdf43c0f372a07495a3de.setIcon(icon_aae23a6fc846bef753bd8df522e16645);
#
#
#         var popup_e960989e7eb390f1ed01ddd9dbb36161 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af06be97b13510f76273671422636545 = $(`&lt;div id=&quot;html_af06be97b13510f76273671422636545&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Squarespace&lt;/div&gt;`)[0];
#                 popup_e960989e7eb390f1ed01ddd9dbb36161.setContent(html_af06be97b13510f76273671422636545);
#
#
#
#         marker_28378ce4533bdf43c0f372a07495a3de.bindPopup(popup_e960989e7eb390f1ed01ddd9dbb36161)
#         ;
#
#
#
#
#             var marker_f0c6d28e038c74d999b4d6c56ff65a2d = L.marker(
#                 [40.69517, -73.9323],
#                 {}
#             ).addTo(map_b8e3bd8d78501916c593623f8e401c41);
#
#
#             var icon_7ce4bd22409f45bd5157e3884f6b02f1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f0c6d28e038c74d999b4d6c56ff65a2d.setIcon(icon_7ce4bd22409f45bd5157e3884f6b02f1);
#
#
#         var popup_a25f142c9827cbfc911a2a2e6ad8672c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4fc1d7ca3e2fe5851ff2c7d996021c95 = $(`&lt;div id=&quot;html_4fc1d7ca3e2fe5851ff2c7d996021c95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Banyan Branch&lt;/div&gt;`)[0];
#                 popup_a25f142c9827cbfc911a2a2e6ad8672c.setContent(html_4fc1d7ca3e2fe5851ff2c7d996021c95);
#
#
#
#         marker_f0c6d28e038c74d999b4d6c56ff65a2d.bindPopup(popup_a25f142c9827cbfc911a2a2e6ad8672c)
#         ;
#
#
#
#
#             var marker_b7d739e93202a01e1b3c733b68f764ea = L.marker(
#                 [40.69517, -73.9323],
#                 {}
#             ).addTo(map_b8e3bd8d78501916c593623f8e401c41);
#
#
#             var icon_89da327952f402afe63531a353d06f96 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconC
