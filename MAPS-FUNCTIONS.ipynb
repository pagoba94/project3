# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd

# %%
df_sf = pd.read_csv("dataframes/df_sanfrancisco.csv")
df_sf
# Out:
#                                              name   latitude   longitude
# 0                                            Digg  37.764726 -122.394523  \
# 1                                             Wix  37.756720 -122.405070
# 2                                       99designs  37.795531 -122.400598
# 3                                          Minted  37.797435 -122.403175
# 4                                     Netbiscuits  37.755037 -122.426442
# 5             Oakland International Airport (OAK)  37.712395 -122.213323
# 6       San Francisco International Airport (SFO)  37.616581 -122.386689
# 7                            Imane's Wonderschool  37.780740 -122.407515
# 8                          Presidio Knolls School  37.773203 -122.413809
# 9                            Alta Plaza Preschool  37.790221 -122.437322
# 10                  Jean Parker Elementary School  37.797687 -122.411024
# 11                       New School San Francisco  37.800775 -122.415078
# 12      Galileo Academy of Science and Technology  37.803767 -122.424217
# 13                     Montgomery St BART Station  37.788862 -122.402116
# 14  Union Square/Market Street MUNI Metro Station  37.787906 -122.406934
# 15                      Powell MUNI Metro Station  37.784458 -122.407591
# 16                                         Monroe  37.797885 -122.405014
# 17                                     The Saloon  37.798551 -122.406989
# 18                                   Pier 23 Cafe  37.803296 -122.400887
# 19                    Enjoy Vegetarian Restaurant  37.795836 -122.405323
# 20       The Lucky Creation Vegetarian Restaurant  37.795217 -122.407437
# 21                         The Plant Cafe Organic  37.791658 -122.402281
# 22                  Alice Marble Basketball Court  37.801449 -122.420352
# 23                                Soma Rec Center  37.778838 -122.406328
# 24                        Berry Basketball Courts  37.772080 -122.397686
# 25                                      Starbucks  37.794601 -122.402669
# 26                                      Starbucks  37.795166 -122.400408
# 27                                      Starbucks  37.797015 -122.398007
# 28                                   Bow Wow Meow  37.796647 -122.421645
# 29                              Bernie's Grooming  37.766882 -122.412719
# 30            Oakland International Airport (OAK)  37.712395 -122.213323
# 31      San Francisco International Airport (SFO)  37.616581 -122.386689
# 32                           Imane's Wonderschool  37.780740 -122.407515
# 33                         Presidio Knolls School  37.773203 -122.413809
# 34                           Alta Plaza Preschool  37.790221 -122.437322
# 35                  Jean Parker Elementary School  37.797687 -122.411024
# 36                       New School San Francisco  37.800775 -122.415078
# 37      Galileo Academy of Science and Technology  37.803767 -122.424217
# 38                     Montgomery St BART Station  37.788862 -122.402116
# 39  Union Square/Market Street MUNI Metro Station  37.787906 -122.406934
# 40                      Powell MUNI Metro Station  37.784458 -122.407591
# 41                                         Monroe  37.797885 -122.405014
# 42                                     The Saloon  37.798551 -122.406989
# 43                                   Pier 23 Cafe  37.803296 -122.400887
# 44                    Enjoy Vegetarian Restaurant  37.795836 -122.405323
# 45       The Lucky Creation Vegetarian Restaurant  37.795217 -122.407437
# 46                         The Plant Cafe Organic  37.791658 -122.402281
# 47                  Alice Marble Basketball Court  37.801449 -122.420352
# 48                                Soma Rec Center  37.778838 -122.406328
# 49                        Berry Basketball Courts  37.772080 -122.397686
# 50                                      Starbucks  37.794601 -122.402669
# 51                                      Starbucks  37.795166 -122.400408
# 52                                      Starbucks  37.797015 -122.398007
# 53                                   Bow Wow Meow  37.796647 -122.421645
# 54                              Bernie's Grooming  37.766882 -122.412719
#
#                             data  distance
# 0                 Design company       NaN
# 1                 Design company       NaN
# 2                 Design company       NaN
# 3                 Design company       NaN
# 4                 Design company       NaN
# 5                        Airport   19161.0
# 6                        Airport   20067.0
# 7                      Preschool    1834.0
# 8                      Preschool    2783.0
# 9                      Preschool    3138.0
# 10  Primary and Secondary School     693.0
# 11  Primary and Secondary School    1125.0
# 12  Primary and Secondary School    2009.0
# 13                 Train Station     888.0
# 14                 Train Station    1074.0
# 15                 Train Station    1447.0
# 16                   Night Clubs     210.0
# 17                   Night Clubs     390.0
# 18                   Night Clubs     746.0
# 19              Vegan Restaurant     203.0
# 20              Vegan Restaurant     411.0
# 21              Vegan Restaurant     559.0
# 22            Basketball Stadium    1580.0
# 23            Basketball Stadium    2006.0
# 24            Basketball Stadium    2814.0
# 25                     Starbucks     257.0
# 26                     Starbucks     309.0
# 27                     Starbucks     453.0
# 28                  Dog Grooming    1639.0
# 29                  Dog Grooming    3467.0
# 30                       Airport   19161.0
# 31                       Airport   20067.0
# 32                     Preschool    1834.0
# 33                     Preschool    2783.0
# 34                     Preschool    3138.0
# 35  Primary and Secondary School     693.0
# 36  Primary and Secondary School    1125.0
# 37  Primary and Secondary School    2009.0
# 38                 Train Station     888.0
# 39                 Train Station    1074.0
# 40                 Train Station    1447.0
# 41                   Night Clubs     210.0
# 42                   Night Clubs     390.0
# 43                   Night Clubs     746.0
# 44              Vegan Restaurant     203.0
# 45              Vegan Restaurant     411.0
# 46              Vegan Restaurant     559.0
# 47            Basketball Stadium    1580.0
# 48            Basketball Stadium    2006.0
# 49            Basketball Stadium    2814.0
# 50                     Starbucks     257.0
# 51                     Starbucks     309.0
# 52                     Starbucks     453.0
# 53                  Dog Grooming    1639.0
# 54                  Dog Grooming    3467.0

# %%
def creating_map(df, lat, lon, zoom=10):

    # Creating a map centered on the coordinates
    city_map = folium.Map(location=[lat, lon], zoom_start=zoom)
    
    data_dict={'Design company': ['pink','briefcase'],
               'Airport': ['blue', 'plane'], 
               'Preschool' : ['lightblue', 'baby-carriage'],
               'Primary and Secondary School': ['darkblue', 'graduation-cap'],
               'Train Station': ['darkred', 'train'],
               'Night Clubs': ['darkpurple', 'martini-glass'],
               'Vegan Restaurant': ['green', 'utensils'],
               'Basketball Stadium':['orange', 'basketball'],
               'Starbucks': ['cadetblue', 'mug-saucer'],
               'Dog Grooming': ['gray', 'dog']
              }
    for key, value in data_dict.items():
        data = df[df['data'] == key]
        # Iterating over the rows of the DataFrame
        for index, row in data.iterrows():
            name = row['name']
            latitude = row['latitude']
            longitude = row['longitude']

             # Creating a custom icon for the design company
            icon = folium.Icon(color=value[0], icon=value[1], prefix='fa')
    
            # Adding a marker to the map for each office
            folium.Marker([latitude, longitude], icon=icon, popup=name).add_to(city_map)

    icon = Icon (color = "red", icon_color = "white", icon = "star", prefix = "fa")
    city_location = Marker(location = [lat, lon], tooltip = "Location", icon = icon)
    city_location.add_to(city_map)

    return city_map

# %%
sf_map=creating_map(df_sf, "37.7968917", "-122.4032027", 14)
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94d5b09e6dfd28f73f4ad4ca14275a80 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94d5b09e6dfd28f73f4ad4ca14275a80&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94d5b09e6dfd28f73f4ad4ca14275a80 = L.map(
#                 &quot;map_94d5b09e6dfd28f73f4ad4ca14275a80&quot;,
#                 {
#                     center: [37.7968917, -122.4032027],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0595df5a7d39e767d7052f68f7dd4dbd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_94d5b09e6dfd28f73f4ad4ca14275a80);
#
#
#             var marker_362807986a1ccd529e2dbdc19db2b3d6 = L.marker(
#                 [37.764726, -122.394523],
#                 {}
#             ).addTo(map_94d5b09e6dfd28f73f4ad4ca14275a80);
#
#
#             var icon_23c895c80d897702e4f943eec56600c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_362807986a1ccd529e2dbdc19db2b3d6.setIcon(icon_23c895c80d897702e4f943eec56600c8);
#
#
#         var popup_82846c02f4f627de2619b50b86a4e649 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a6cbf063420be8818ca8cbe2ecd82efd = $(`&lt;div id=&quot;html_a6cbf063420be8818ca8cbe2ecd82efd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Digg&lt;/div&gt;`)[0];
#                 popup_82846c02f4f627de2619b50b86a4e649.setContent(html_a6cbf063420be8818ca8cbe2ecd82efd);
#
#
#
#         marker_362807986a1ccd529e2dbdc19db2b3d6.bindPopup(popup_82846c02f4f627de2619b50b86a4e649)
#         ;
#
#
#
#
#             var marker_d4dbb81edd77e32dfd3de6b44052ba1a = L.marker(
#                 [37.75672, -122.40507],
#                 {}
#             ).addTo(map_94d5b09e6dfd28f73f4ad4ca14275a80);
#
#
#             var icon_f3427dca36f882cc5c816ad4c2282a12 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d4dbb81edd77e32dfd3de6b44052ba1a.setIcon(icon_f3427dca36f882cc5c816ad4c2282a12);
#
#
#         var popup_e911f7213f6fb199e5f1d585181baf53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_81564acbcc26203460250aa5bc4c07f8 = $(`&lt;div id=&quot;html_81564acbcc26203460250aa5bc4c07f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wix&lt;/div&gt;`)[0];
#                 popup_e911f7213f6fb199e5f1d585181baf53.setContent(html_81564acbcc26203460250aa5bc4c07f8);
#
#
#
#         marker_d4dbb81edd77e32dfd3de6b44052ba1a.bindPopup(popup_e911f7213f6fb199e5f1d585181baf53)
#         ;
#
#
#
#
#             var marker_608fe0c66599b8f61fd150e69ca376e9 = L.marker(
#                 [37.7955307, -122.4005983],
#                 {}
#             ).addTo(map_94d5b09e6dfd28f73f4ad4ca14275a80);
#
#
#             var icon_5d5cfa5f7fcd9ed0ddc3ff6c33b109a4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_608fe0c66599b8f61fd150e69ca376e9.setIcon(icon_5d5cfa5f7fcd9ed0ddc3ff6c33b109a4);
#
#
#         var popup_13a8a407f3f0afa18bf3a35312d30226 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8481d40f458a3868bbe1549d08e83704 = $(`&lt;div id=&quot;html_8481d40f458a3868bbe1549d08e83704&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;99designs&lt;/div&gt;`)[0];
#                 popup_13a8a407f3f0afa18bf3a35312d30226.setContent(html_8481d40f458a3868bbe1549d08e83704);
#
#
#
#         marker_608fe0c66599b8f61fd150e69ca376e9.bindPopup(popup_13a8a407f3f0afa18bf3a35312d30226)
#         ;
#
#
#
#
#             var marker_5351908c5947060196766e5a8dcd2a8e = L.marker(
#                 [37.797435, -122.403175],
#                 {}
#             ).addTo(map_94d5b09e6dfd28f73f4ad4ca14275a80);
#
#
#             var icon_3f66843bba8cc305e0d9243e8e813fc8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&q

# %%
df_lon = pd.read_csv("dataframes/df_london.csv")
df_lon
# Out:
#                                         name   latitude  longitude
# 0                                Netbiscuits  51.513248  -0.154738  \
# 1                                  Moonfruit  51.519130  -0.110160
# 2                  London City Airport (LCY)  51.504029   0.049552
# 3              London Heathrow Airport (LHR)  51.470584  -0.454958
# 4                        Home Star Childcare  51.513242  -0.141109
# 5                           Dyason Preschool  51.489346  -0.088069
# 6                     Turning Earth Ceramics  51.534412  -0.075928
# 7                      Netley Primary School  51.527677  -0.140121
# 8                         Eaton House School  51.494096  -0.154935
# 9                        Westminster Academy  51.521012  -0.192724
# 10                               Marble Arch  51.513632  -0.158366
# 11   Edgware Road London Underground Station  51.520204  -0.167106
# 12  Oxford Circus London Underground Station  51.515163  -0.141682
# 13                                 Annabel's  51.509132  -0.146903
# 14                               Tape London  51.514330  -0.144478
# 15                               The Phoenix  51.516043  -0.143712
# 16                              Plants by De  51.513315  -0.150040
# 17                               Neat Burger  51.514627  -0.142740
# 18                                       Kin  51.519444  -0.140363
# 19         Tabard Gardens - Basketball Court  51.514811  -0.174869
# 20           Lisson Grove - Basketball Court  51.525673  -0.168182
# 21                            Netball Courts  51.536528  -0.137030
# 22                                 Starbucks  51.514326  -0.152723
# 23                                 Starbucks  51.514765  -0.150258
# 24                                 Starbucks  51.513880  -0.149514
# 25                 London City Airport (LCY)  51.504029   0.049552
# 26             London Heathrow Airport (LHR)  51.470584  -0.454958
# 27                       Home Star Childcare  51.513242  -0.141109
# 28                          Dyason Preschool  51.489346  -0.088069
# 29                    Turning Earth Ceramics  51.534412  -0.075928
# 30                     Netley Primary School  51.527677  -0.140121
# 31                        Eaton House School  51.494096  -0.154935
# 32                       Westminster Academy  51.521012  -0.192724
# 33                               Marble Arch  51.513632  -0.158366
# 34  Oxford Circus London Underground Station  51.515163  -0.141682
# 35   Edgware Road London Underground Station  51.520204  -0.167106
# 36                                 Annabel's  51.509132  -0.146903
# 37                               Tape London  51.514330  -0.144478
# 38                               The Phoenix  51.516043  -0.143712
# 39                              Plants by De  51.513315  -0.150040
# 40                               Neat Burger  51.514627  -0.142740
# 41                                       Kin  51.519444  -0.140363
# 42         Tabard Gardens - Basketball Court  51.514811  -0.174869
# 43           Lisson Grove - Basketball Court  51.525673  -0.168182
# 44     Argyle Square Public Basketball Court  51.529063  -0.122972
# 45                                 Starbucks  51.514326  -0.152723
# 46                                 Starbucks  51.514765  -0.150258
# 47                                 Starbucks  51.513880  -0.149514
#
#                             data  distance
# 0                 Design company       NaN
# 1                 Design company       NaN
# 2                        Airport   14300.0
# 3                        Airport   21466.0
# 4                      Preschool    1075.0
# 5                      Preschool    5446.0
# 6                      Preschool    6069.0
# 7   Primary and Secondary School    1971.0
# 8   Primary and Secondary School    2153.0
# 9   Primary and Secondary School    2583.0
# 10                 Train Station     114.0
# 11                 Train Station    1039.0
# 12                 Train Station    1041.0
# 13                   Night Clubs     819.0
# 14                   Night Clubs     854.0
# 15                   Night Clubs     958.0
# 16              Vegan Restaurant     449.0
# 17              Vegan Restaurant     978.0
# 18              Vegan Restaurant    1312.0
# 19            Basketball Stadium    1263.0
# 20            Basketball Stadium    1586.0
# 21            Basketball Stadium    2891.0
# 22                     Starbucks     355.0
# 23                     Starbucks     461.0
# 24                     Starbucks     510.0
# 25                       Airport   14166.0
# 26                       Airport   21592.0
# 27                     Preschool     942.0
# 28                     Preschool    5322.0
# 29                     Preschool    5953.0
# 30  Primary and Secondary School    1910.0
# 31  Primary and Secondary School    2132.0
# 32  Primary and Secondary School    2714.0
# 33                 Train Station     248.0
# 34                 Train Station     915.0
# 35                 Train Station    1147.0
# 36                   Night Clubs     701.0
# 37                   Night Clubs     724.0
# 38                   Night Clubs     840.0
# 39              Vegan Restaurant     316.0
# 40              Vegan Restaurant     849.0
# 41              Vegan Restaurant    1208.0
# 42            Basketball Stadium    1397.0
# 43            Basketball Stadium    1672.0
# 44            Basketball Stadium    2821.0
# 45                     Starbucks     241.0
# 46                     Starbucks     344.0
# 47                     Starbucks     380.0

# %%
lon_map=creating_map(df_lon, '51.5134019','-0.1566624', 14) 
lon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6104f07c1e819d5a519f48bf73689987 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6104f07c1e819d5a519f48bf73689987&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6104f07c1e819d5a519f48bf73689987 = L.map(
#                 &quot;map_6104f07c1e819d5a519f48bf73689987&quot;,
#                 {
#                     center: [51.5134019, -0.1566624],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_296c1055c116513d576a9ae0016c3722 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6104f07c1e819d5a519f48bf73689987);
#
#
#             var marker_34d5530062c6111523f1a5ddd38fbe62 = L.marker(
#                 [51.513248, -0.1547377],
#                 {}
#             ).addTo(map_6104f07c1e819d5a519f48bf73689987);
#
#
#             var icon_fc03905a5a1ef445bf83bd4e139afab0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_34d5530062c6111523f1a5ddd38fbe62.setIcon(icon_fc03905a5a1ef445bf83bd4e139afab0);
#
#
#         var popup_935db9f1f7236e24834a9516dfc5555a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_372fcd6b7d53d067390d93462e9af840 = $(`&lt;div id=&quot;html_372fcd6b7d53d067390d93462e9af840&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Netbiscuits&lt;/div&gt;`)[0];
#                 popup_935db9f1f7236e24834a9516dfc5555a.setContent(html_372fcd6b7d53d067390d93462e9af840);
#
#
#
#         marker_34d5530062c6111523f1a5ddd38fbe62.bindPopup(popup_935db9f1f7236e24834a9516dfc5555a)
#         ;
#
#
#
#
#             var marker_277683f1a3f69526a6b930d02ee951a6 = L.marker(
#                 [51.51913, -0.11016],
#                 {}
#             ).addTo(map_6104f07c1e819d5a519f48bf73689987);
#
#
#             var icon_23cdbdcbd1694e5514c41924fc413504 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_277683f1a3f69526a6b930d02ee951a6.setIcon(icon_23cdbdcbd1694e5514c41924fc413504);
#
#
#         var popup_efb7c2b018f0fd909b440773d563c3c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd1830f29951e8b17594df82789214bf = $(`&lt;div id=&quot;html_fd1830f29951e8b17594df82789214bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Moonfruit&lt;/div&gt;`)[0];
#                 popup_efb7c2b018f0fd909b440773d563c3c7.setContent(html_fd1830f29951e8b17594df82789214bf);
#
#
#
#         marker_277683f1a3f69526a6b930d02ee951a6.bindPopup(popup_efb7c2b018f0fd909b440773d563c3c7)
#         ;
#
#
#
#
#             var marker_c5d7a2f105832d92064bbc2f5d9326a9 = L.marker(
#                 [51.504029, 0.049552],
#                 {}
#             ).addTo(map_6104f07c1e819d5a519f48bf73689987);
#
#
#             var icon_da7c134b6829c3524adf7e09aa887a63 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c5d7a2f105832d92064bbc2f5d9326a9.setIcon(icon_da7c134b6829c3524adf7e09aa887a63);
#
#
#         var popup_4266558d7167e266c10f0ee2bce6cb93 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c30a397df70e38b03ce8c50012f83e1 = $(`&lt;div id=&quot;html_5c30a397df70e38b03ce8c50012f83e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;London City Airport (LCY)&lt;/div&gt;`)[0];
#                 popup_4266558d7167e266c10f0ee2bce6cb93.setContent(html_5c30a397df70e38b03ce8c50012f83e1);
#
#
#
#         marker_c5d7a2f105832d92064bbc2f5d9326a9.bindPopup(popup_4266558d7167e266c10f0ee2bce6cb93)
#         ;
#
#
#
#
#             var marker_1d45e6daeedc2e925d810ddfdf32ab8b = L.marker(
#                 [51.470584, -0.454958],
#                 {}
#             ).addTo(map_6104f07c1e819d5a519f48bf73689987);
#
#
#             var icon_f4798a6ba74c996dcad7f129fef4ed56 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;ic

# %%
df_nyc = pd.read_csv("dataframes/df_newyork.csv")
df_nyc
# Out:
#                                            name   latitude  longitude
# 0                                   Gilt Groupe  40.747270 -73.980064  \
# 1                                   Squarespace  40.720810 -74.000870
# 2                                 Banyan Branch  40.695170 -73.932300
# 3                                   Netbiscuits  40.695170 -73.932300
# 4                       LaGuardia Airport (LGA)  40.774527 -73.871941
# 5    Newark Liberty International Airport (EWR)  40.690377 -74.177145
# 6   John F. Kennedy International Airport (JFK)  40.643864 -73.782268
# 7                           Metrokids Preschool  40.748664 -73.970435
# 8                          Academy of St Joseph  40.732732 -74.000991
# 9                                FIAF Preschool  40.763926 -73.970723
# 10                           Xavier High School  40.738023 -73.994868
# 11          United Nations International School  40.736339 -73.973319
# 12    NY SPORTS 4 KIDS William T. Harris School  40.744389 -74.000840
# 13                         MTA Subway - 23rd St  40.740187 -73.986656
# 14                         MTA Subway - 23rd St  40.743148 -73.992887
# 15                          33rd Street Station  40.750333 -73.990549
# 16                              Hidden Lane Bar  40.734657 -73.987662
# 17                        Somewhere Nowhere NYC  40.744283 -73.992800
# 18                                      Nowhere  40.731787 -73.984100
# 19                           24th St Vegan Cafe  40.738894 -73.980623
# 20                                   Sweetgreen  40.738122 -73.991204
# 21                                 Planta Queen  40.744459 -73.988309
# 22                  Basketball Gym At The Dylan  40.746752 -73.985298
# 23                             Basketball Court  40.733342 -73.980450
# 24    Playground 9- Basketball Court/Sprinklers  40.732120 -73.979747
# 25                                    Starbucks  40.740519 -73.984355
# 26                                    Starbucks  40.740187 -73.986656
# 27                                    Starbucks  40.738035 -73.988450
# 28                             Reme's Oggi Pets  40.756870 -73.964245
# 29                    Ruby & Jack's Doggy Shack  40.761426 -73.963373
# 30                                The Salty Paw  40.707471 -74.001652
#
#                             data  distance
# 0                 Design company       NaN
# 1                 Design company       NaN
# 2                 Design company       NaN
# 3                 Design company       NaN
# 4                        Airport   10447.0
# 5                        Airport   17068.0
# 6                        Airport   19901.0
# 7                      Preschool    1563.0
# 8                      Preschool    1571.0
# 9                      Preschool    2930.0
# 10  Primary and Secondary School     841.0
# 11  Primary and Secondary School    1054.0
# 12  Primary and Secondary School    1401.0
# 13                 Train Station     122.0
# 14                 Train Station     755.0
# 15                 Train Station    1010.0
# 16                   Night Clubs     623.0
# 17                   Night Clubs     812.0
# 18                   Night Clubs     905.0
# 19              Vegan Restaurant     356.0
# 20              Vegan Restaurant     559.0
# 21              Vegan Restaurant     573.0
# 22            Basketball Stadium     749.0
# 23            Basketball Stadium     950.0
# 24            Basketball Stadium     955.0
# 25                     Starbucks      91.0
# 26                     Starbucks     165.0
# 27                     Starbucks     356.0
# 28                  Dog Grooming    2569.0
# 29                  Dog Grooming    2995.0
# 30                  Dog Grooming    3842.0

# %%
nyc_map=creating_map(df_nyc,'40.7398872','-73.9850319', 14) 
nyc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bcb70b84e83e6554dfd79be01cf99bbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bcb70b84e83e6554dfd79be01cf99bbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bcb70b84e83e6554dfd79be01cf99bbc = L.map(
#                 &quot;map_bcb70b84e83e6554dfd79be01cf99bbc&quot;,
#                 {
#                     center: [40.7398872, -73.9850319],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a647711df676b205f82b3a4b87e5716d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bcb70b84e83e6554dfd79be01cf99bbc);
#
#
#             var marker_4f38992d9fc61cdd49e2554b62edbd58 = L.marker(
#                 [40.74727, -73.9800645],
#                 {}
#             ).addTo(map_bcb70b84e83e6554dfd79be01cf99bbc);
#
#
#             var icon_002c73b8c0b8dd4fd7d8a49a06f34249 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4f38992d9fc61cdd49e2554b62edbd58.setIcon(icon_002c73b8c0b8dd4fd7d8a49a06f34249);
#
#
#         var popup_89b3cdf1662952fd0cd473d27713d8bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ac20d4d2011e955f97127d6d0703c05 = $(`&lt;div id=&quot;html_2ac20d4d2011e955f97127d6d0703c05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gilt Groupe&lt;/div&gt;`)[0];
#                 popup_89b3cdf1662952fd0cd473d27713d8bd.setContent(html_2ac20d4d2011e955f97127d6d0703c05);
#
#
#
#         marker_4f38992d9fc61cdd49e2554b62edbd58.bindPopup(popup_89b3cdf1662952fd0cd473d27713d8bd)
#         ;
#
#
#
#
#             var marker_9798771d82cab50caba48a0fee49975e = L.marker(
#                 [40.72081, -74.00087],
#                 {}
#             ).addTo(map_bcb70b84e83e6554dfd79be01cf99bbc);
#
#
#             var icon_c6c155bee6d14026414a204c9fc30480 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9798771d82cab50caba48a0fee49975e.setIcon(icon_c6c155bee6d14026414a204c9fc30480);
#
#
#         var popup_23c271470e04b348e1fba83efa3c59f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e181cfef2c7ca1f49d67d5d1bc3cf692 = $(`&lt;div id=&quot;html_e181cfef2c7ca1f49d67d5d1bc3cf692&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Squarespace&lt;/div&gt;`)[0];
#                 popup_23c271470e04b348e1fba83efa3c59f7.setContent(html_e181cfef2c7ca1f49d67d5d1bc3cf692);
#
#
#
#         marker_9798771d82cab50caba48a0fee49975e.bindPopup(popup_23c271470e04b348e1fba83efa3c59f7)
#         ;
#
#
#
#
#             var marker_3ffa0d4cf6a1ca33fa63826a8f551bb6 = L.marker(
#                 [40.69517, -73.9323],
#                 {}
#             ).addTo(map_bcb70b84e83e6554dfd79be01cf99bbc);
#
#
#             var icon_caf5a33b50573eb6104e918e61d5617d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3ffa0d4cf6a1ca33fa63826a8f551bb6.setIcon(icon_caf5a33b50573eb6104e918e61d5617d);
#
#
#         var popup_26f870894382274756b79a70cacf183b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9672e8c6d08576942f733c128471f999 = $(`&lt;div id=&quot;html_9672e8c6d08576942f733c128471f999&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Banyan Branch&lt;/div&gt;`)[0];
#                 popup_26f870894382274756b79a70cacf183b.setContent(html_9672e8c6d08576942f733c128471f999);
#
#
#
#         marker_3ffa0d4cf6a1ca33fa63826a8f551bb6.bindPopup(popup_26f870894382274756b79a70cacf183b)
#         ;
#
#
#
#
#             var marker_03b9e0171452eb560dd529b042c721d7 = L.marker(
#                 [40.69517, -73.9323],
#                 {}
#             ).addTo(map_bcb70b84e83e6554dfd79be01cf99bbc);
#
#
#             var icon_8c4827c6bf196d74333d55e78d135793 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconC
