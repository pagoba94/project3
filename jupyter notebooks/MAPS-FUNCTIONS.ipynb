# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd

# %%
def creating_map(df, lat, lon, zoom=10):

    # Creating a map centered on the coordinates
    city_map = folium.Map(location=[lat, lon], zoom_start=zoom)
    
    data_dict={'Design company': ['pink','briefcase'],
               'Airport': ['blue', 'plane'], 
               'Preschool' : ['lightblue', 'baby-carriage'],
               'Primary and Secondary School': ['darkblue', 'graduation-cap'],
               'Train Station': ['darkred', 'train'],
               'Night Clubs': ['darkpurple', 'martini-glass'],
               'Vegan Restaurant': ['green', 'utensils'],
               'Basketball Stadium':['orange', 'basketball'],
               'Starbucks': ['cadetblue', 'mug-saucer'],
               'Dog Grooming': ['gray', 'dog']
              }
    for key, value in data_dict.items():
        data = df[df['data'] == key]
        # Iterating over the rows of the DataFrame
        for index, row in data.iterrows():
            name = row['name']
            latitude = row['latitude']
            longitude = row['longitude']

             # Creating a custom icon for the design company
            icon = folium.Icon(color=value[0], icon=value[1], prefix='fa')
    
            # Adding a marker to the map for each office
            folium.Marker([latitude, longitude], icon=icon, popup=name).add_to(city_map)

    icon = Icon (color = "red", icon_color = "white", icon = "star", prefix = "fa")
    city_location = Marker(location = [lat, lon], tooltip = "Location", icon = icon)
    city_location.add_to(city_map)

    return city_map

# %% [markdown]
# # Creating San Francisco map

# %%
df_sf = pd.read_csv("../dataframes/df_sanfrancisco.csv")
df_sf
# Out:
#                                    name   latitude   longitude
# 0                                  Digg  37.764726 -122.394523  \
# 1                                   Wix  37.756720 -122.405070
# 2                             99designs  37.795531 -122.400598
# 3                                Minted  37.797435 -122.403175
# 4                           Netbiscuits  37.755037 -122.426442
# 5   Oakland International Airport (OAK)  37.712395 -122.213323
# 6                  Imane's Wonderschool  37.780740 -122.407515
# 7         Jean Parker Elementary School  37.797687 -122.411024
# 8            Montgomery St BART Station  37.788862 -122.402116
# 9                                Monroe  37.797885 -122.405014
# 10          Enjoy Vegetarian Restaurant  37.795836 -122.405323
# 11        Alice Marble Basketball Court  37.801449 -122.420352
# 12                            Starbucks  37.794601 -122.402669
# 13                         Bow Wow Meow  37.796647 -122.421645
#
#                             data  distance           city
# 0                 Design company       NaN  San Francisco
# 1                 Design company       NaN  San Francisco
# 2                 Design company       NaN  San Francisco
# 3                 Design company       NaN  San Francisco
# 4                 Design company       NaN  San Francisco
# 5                        Airport   19161.0  San Francisco
# 6                      Preschool    1834.0  San Francisco
# 7   Primary and Secondary School     693.0  San Francisco
# 8                  Train Station     888.0  San Francisco
# 9                    Night Clubs     210.0  San Francisco
# 10              Vegan Restaurant     203.0  San Francisco
# 11            Basketball Stadium    1580.0  San Francisco
# 12                     Starbucks     257.0  San Francisco
# 13                  Dog Grooming    1639.0  San Francisco

# %%
sf_map=creating_map(df_sf, "37.7968917", "-122.4032027", 14)
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a7cbb316be89c3b6349053d5c140edb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a7cbb316be89c3b6349053d5c140edb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a7cbb316be89c3b6349053d5c140edb = L.map(
#                 &quot;map_0a7cbb316be89c3b6349053d5c140edb&quot;,
#                 {
#                     center: [37.7968917, -122.4032027],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4587530b182aec6945aebe0e3d37fc31 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0a7cbb316be89c3b6349053d5c140edb);
#
#
#             var marker_2bfb4958615f5807c524bf4a46969ec9 = L.marker(
#                 [37.764726, -122.394523],
#                 {}
#             ).addTo(map_0a7cbb316be89c3b6349053d5c140edb);
#
#
#             var icon_807b3582c9042339bd2a12c1ee7f5400 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2bfb4958615f5807c524bf4a46969ec9.setIcon(icon_807b3582c9042339bd2a12c1ee7f5400);
#
#
#         var popup_06a534ea76d0327ed54c815d41a38e63 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb86f2bf0f3ac4b489635cf4a7f23318 = $(`&lt;div id=&quot;html_bb86f2bf0f3ac4b489635cf4a7f23318&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Digg&lt;/div&gt;`)[0];
#                 popup_06a534ea76d0327ed54c815d41a38e63.setContent(html_bb86f2bf0f3ac4b489635cf4a7f23318);
#
#
#
#         marker_2bfb4958615f5807c524bf4a46969ec9.bindPopup(popup_06a534ea76d0327ed54c815d41a38e63)
#         ;
#
#
#
#
#             var marker_3ef6a6ad5cc94051cd011ab003a459df = L.marker(
#                 [37.75672, -122.40507],
#                 {}
#             ).addTo(map_0a7cbb316be89c3b6349053d5c140edb);
#
#
#             var icon_29c135676ab9f87c2b43076415a9ca1c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3ef6a6ad5cc94051cd011ab003a459df.setIcon(icon_29c135676ab9f87c2b43076415a9ca1c);
#
#
#         var popup_f42a2913c8dba8b51236c59fa5be4abf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c473c131777919562410ba1f8d7beb13 = $(`&lt;div id=&quot;html_c473c131777919562410ba1f8d7beb13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wix&lt;/div&gt;`)[0];
#                 popup_f42a2913c8dba8b51236c59fa5be4abf.setContent(html_c473c131777919562410ba1f8d7beb13);
#
#
#
#         marker_3ef6a6ad5cc94051cd011ab003a459df.bindPopup(popup_f42a2913c8dba8b51236c59fa5be4abf)
#         ;
#
#
#
#
#             var marker_ea03784484662e303acf2d0c6987e80d = L.marker(
#                 [37.7955307, -122.4005983],
#                 {}
#             ).addTo(map_0a7cbb316be89c3b6349053d5c140edb);
#
#
#             var icon_743a803b1540542ef168f93938906c20 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ea03784484662e303acf2d0c6987e80d.setIcon(icon_743a803b1540542ef168f93938906c20);
#
#
#         var popup_c4cecf8e5d9deac1c4f175c651d4b144 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07b8bb7d5998397aa800900b33f1a0d0 = $(`&lt;div id=&quot;html_07b8bb7d5998397aa800900b33f1a0d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;99designs&lt;/div&gt;`)[0];
#                 popup_c4cecf8e5d9deac1c4f175c651d4b144.setContent(html_07b8bb7d5998397aa800900b33f1a0d0);
#
#
#
#         marker_ea03784484662e303acf2d0c6987e80d.bindPopup(popup_c4cecf8e5d9deac1c4f175c651d4b144)
#         ;
#
#
#
#
#             var marker_0cd54adb6e8b03969bb364ca11329db1 = L.marker(
#                 [37.797435, -122.403175],
#                 {}
#             ).addTo(map_0a7cbb316be89c3b6349053d5c140edb);
#
#
#             var icon_29b03519ef0ba77663e6fc962351650a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&q

# %% [markdown]
# # Creating London map

# %%
df_lon = pd.read_csv("dataframes/df_london.csv")
df_lon
# Out:
#                                  name   latitude  longitude
# 0                         Netbiscuits  51.513248  -0.154738  \
# 1                           Moonfruit  51.519130  -0.110160
# 2           London City Airport (LCY)  51.504029   0.049552
# 3                 Home Star Childcare  51.513242  -0.141109
# 4               Netley Primary School  51.527677  -0.140121
# 5                         Marble Arch  51.513632  -0.158366
# 6                           Annabel's  51.509132  -0.146903
# 7                        Plants by De  51.513315  -0.150040
# 8   Tabard Gardens - Basketball Court  51.514811  -0.174869
# 9                           Starbucks  51.514326  -0.152723
# 10             Jessica's Dog Grooming  51.514184  -0.186336
#
#                             data  distance    city
# 0                 Design company       NaN  London
# 1                 Design company       NaN  London
# 2                        Airport   14166.0  London
# 3                      Preschool     942.0  London
# 4   Primary and Secondary School    1910.0  London
# 5                  Train Station     248.0  London
# 6                    Night Clubs     701.0  London
# 7               Vegan Restaurant     316.0  London
# 8             Basketball Stadium    1397.0  London
# 9                      Starbucks     241.0  London
# 10                  Dog Grooming    1500.0  London

# %%
lon_map=creating_map(df_lon, '51.5134019','-0.1566624', 14) 
lon_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ed15a241d42e46f9d859e4aee941077 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ed15a241d42e46f9d859e4aee941077&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ed15a241d42e46f9d859e4aee941077 = L.map(
#                 &quot;map_1ed15a241d42e46f9d859e4aee941077&quot;,
#                 {
#                     center: [51.5134019, -0.1566624],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17c2ef8b2da8cf191ab0aac51e382aee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1ed15a241d42e46f9d859e4aee941077);
#
#
#             var marker_bc586c12098e413fa2e3a0babbfe660f = L.marker(
#                 [51.513248, -0.1547377],
#                 {}
#             ).addTo(map_1ed15a241d42e46f9d859e4aee941077);
#
#
#             var icon_229d39dde026b917871de1757fc6d4d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bc586c12098e413fa2e3a0babbfe660f.setIcon(icon_229d39dde026b917871de1757fc6d4d1);
#
#
#         var popup_cc6a6a54fd709f0a5c95baeb1d1c36ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e217f12d2ec96c83d46e52df20499295 = $(`&lt;div id=&quot;html_e217f12d2ec96c83d46e52df20499295&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Netbiscuits&lt;/div&gt;`)[0];
#                 popup_cc6a6a54fd709f0a5c95baeb1d1c36ab.setContent(html_e217f12d2ec96c83d46e52df20499295);
#
#
#
#         marker_bc586c12098e413fa2e3a0babbfe660f.bindPopup(popup_cc6a6a54fd709f0a5c95baeb1d1c36ab)
#         ;
#
#
#
#
#             var marker_d800a512c25ff91a2f7a82ae7e9d1c6a = L.marker(
#                 [51.51913, -0.11016],
#                 {}
#             ).addTo(map_1ed15a241d42e46f9d859e4aee941077);
#
#
#             var icon_5c64b2b0547d10da689610d3ca150ce9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d800a512c25ff91a2f7a82ae7e9d1c6a.setIcon(icon_5c64b2b0547d10da689610d3ca150ce9);
#
#
#         var popup_3531a24a6a811364572b9669303ba998 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25c9a30d18a77231ec2fb0908afa8d8a = $(`&lt;div id=&quot;html_25c9a30d18a77231ec2fb0908afa8d8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Moonfruit&lt;/div&gt;`)[0];
#                 popup_3531a24a6a811364572b9669303ba998.setContent(html_25c9a30d18a77231ec2fb0908afa8d8a);
#
#
#
#         marker_d800a512c25ff91a2f7a82ae7e9d1c6a.bindPopup(popup_3531a24a6a811364572b9669303ba998)
#         ;
#
#
#
#
#             var marker_ecdb17ed231b8293a780714dfca4d715 = L.marker(
#                 [51.504029, 0.049552],
#                 {}
#             ).addTo(map_1ed15a241d42e46f9d859e4aee941077);
#
#
#             var icon_2c5ce9d5cd581eb74095e7bf5502321a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ecdb17ed231b8293a780714dfca4d715.setIcon(icon_2c5ce9d5cd581eb74095e7bf5502321a);
#
#
#         var popup_d4a355be2ff09ae58b445a41d32d8ccf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dde6e67488a760209d94745c695c7b59 = $(`&lt;div id=&quot;html_dde6e67488a760209d94745c695c7b59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;London City Airport (LCY)&lt;/div&gt;`)[0];
#                 popup_d4a355be2ff09ae58b445a41d32d8ccf.setContent(html_dde6e67488a760209d94745c695c7b59);
#
#
#
#         marker_ecdb17ed231b8293a780714dfca4d715.bindPopup(popup_d4a355be2ff09ae58b445a41d32d8ccf)
#         ;
#
#
#
#
#             var marker_80e56c89df8febf89ea9cf60b58e93b6 = L.marker(
#                 [51.513242, -0.141109],
#                 {}
#             ).addTo(map_1ed15a241d42e46f9d859e4aee941077);
#
#
#             var icon_992d9c5189e3439bfc7ca31de0dcb33f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;baby-carriage&quot;,

# %% [markdown]
# # Creating New York map

# %%
df_nyc = pd.read_csv("dataframes/df_newyork.csv")
df_nyc
# Out:
#                            name   latitude  longitude
# 0                   Gilt Groupe  40.747270 -73.980064  \
# 1                   Squarespace  40.720810 -74.000870
# 2                 Banyan Branch  40.695170 -73.932300
# 3                   Netbiscuits  40.695170 -73.932300
# 4       LaGuardia Airport (LGA)  40.774527 -73.871941
# 5           Metrokids Preschool  40.748664 -73.970435
# 6            Xavier High School  40.738023 -73.994868
# 7          MTA Subway - 23rd St  40.740187 -73.986656
# 8               Hidden Lane Bar  40.734657 -73.987662
# 9            24th St Vegan Cafe  40.738894 -73.980623
# 10  Basketball Gym At The Dylan  40.746752 -73.985298
# 11                    Starbucks  40.740519 -73.984355
# 12             Reme's Oggi Pets  40.756870 -73.964245
#
#                             data  distance      city
# 0                 Design company       NaN  New York
# 1                 Design company       NaN  New York
# 2                 Design company       NaN  New York
# 3                 Design company       NaN  New York
# 4                        Airport   10447.0  New York
# 5                      Preschool    1563.0  New York
# 6   Primary and Secondary School     841.0  New York
# 7                  Train Station     122.0  New York
# 8                    Night Clubs     623.0  New York
# 9               Vegan Restaurant     356.0  New York
# 10            Basketball Stadium     749.0  New York
# 11                     Starbucks      91.0  New York
# 12                  Dog Grooming    2569.0  New York

# %%
nyc_map=creating_map(df_nyc,'40.7398872','-73.9850319', 14) 
nyc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e215aaaf0f8a133bcc5cc7921146167 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e215aaaf0f8a133bcc5cc7921146167&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e215aaaf0f8a133bcc5cc7921146167 = L.map(
#                 &quot;map_9e215aaaf0f8a133bcc5cc7921146167&quot;,
#                 {
#                     center: [40.7398872, -73.9850319],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_522f83850e9ac14e49499505a1ea3af8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e215aaaf0f8a133bcc5cc7921146167);
#
#
#             var marker_8cc58aeee006212d69e12e6b099c6d07 = L.marker(
#                 [40.74727, -73.9800645],
#                 {}
#             ).addTo(map_9e215aaaf0f8a133bcc5cc7921146167);
#
#
#             var icon_49111a0aa8e41a859fc8b7b3f0d1c539 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8cc58aeee006212d69e12e6b099c6d07.setIcon(icon_49111a0aa8e41a859fc8b7b3f0d1c539);
#
#
#         var popup_3c533209048983051398a264ca7de6f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ce13accc3dcccca01620b33982a778d = $(`&lt;div id=&quot;html_0ce13accc3dcccca01620b33982a778d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gilt Groupe&lt;/div&gt;`)[0];
#                 popup_3c533209048983051398a264ca7de6f6.setContent(html_0ce13accc3dcccca01620b33982a778d);
#
#
#
#         marker_8cc58aeee006212d69e12e6b099c6d07.bindPopup(popup_3c533209048983051398a264ca7de6f6)
#         ;
#
#
#
#
#             var marker_c96ec4984eff83c104c8ab2a10a008e0 = L.marker(
#                 [40.72081, -74.00087],
#                 {}
#             ).addTo(map_9e215aaaf0f8a133bcc5cc7921146167);
#
#
#             var icon_15e19b9282e78cce7450c4b61f2df45b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c96ec4984eff83c104c8ab2a10a008e0.setIcon(icon_15e19b9282e78cce7450c4b61f2df45b);
#
#
#         var popup_50c8551febf9362de1d43490da87b035 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65ae2d90681266a53b2a91b4bb19e9b4 = $(`&lt;div id=&quot;html_65ae2d90681266a53b2a91b4bb19e9b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Squarespace&lt;/div&gt;`)[0];
#                 popup_50c8551febf9362de1d43490da87b035.setContent(html_65ae2d90681266a53b2a91b4bb19e9b4);
#
#
#
#         marker_c96ec4984eff83c104c8ab2a10a008e0.bindPopup(popup_50c8551febf9362de1d43490da87b035)
#         ;
#
#
#
#
#             var marker_daa26564d1ba6787ca2a89ab38ec2233 = L.marker(
#                 [40.69517, -73.9323],
#                 {}
#             ).addTo(map_9e215aaaf0f8a133bcc5cc7921146167);
#
#
#             var icon_b28e48f230ecfe1abaa7211c3f58b073 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_daa26564d1ba6787ca2a89ab38ec2233.setIcon(icon_b28e48f230ecfe1abaa7211c3f58b073);
#
#
#         var popup_d756e9f79f42fe8f5f3157df2f386434 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12c1d8929776664469cd3fbcdce9445b = $(`&lt;div id=&quot;html_12c1d8929776664469cd3fbcdce9445b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Banyan Branch&lt;/div&gt;`)[0];
#                 popup_d756e9f79f42fe8f5f3157df2f386434.setContent(html_12c1d8929776664469cd3fbcdce9445b);
#
#
#
#         marker_daa26564d1ba6787ca2a89ab38ec2233.bindPopup(popup_d756e9f79f42fe8f5f3157df2f386434)
#         ;
#
#
#
#
#             var marker_0cf5d09312e08aa97d5da3342ff27bfa = L.marker(
#                 [40.69517, -73.9323],
#                 {}
#             ).addTo(map_9e215aaaf0f8a133bcc5cc7921146167);
#
#
#             var icon_d04488cfc8b1fd274882e047dec0d61f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconC
