# %%
from getpass import getpass
from dotenv import load_dotenv
import pandas as pd
import requests
import os
import folium
import pandas as pd

# %%
load_dotenv()
# Out:
# True

# %%
token = os.getenv("token")

# %%
df_sanfrancisco = pd.read_csv("../dataframes/df_sanfrancisco.csv")
df_london = pd.read_csv("../dataframes/df_london.csv")
df_newyork = pd.read_csv("../dataframes/df_newyork.csv")

# %%
def category_from_foursquare (lon, lat, category):

    url = f"https://api.foursquare.com/v3/places/search?&ll={lon}%2C{lat}&categories={category}&sort=DISTANCE&limit=3"
    
    headers = {
        "accept": "application/json",
        "Authorization": token
    }

    response = requests.get(url, headers=headers).json()
    return response

# %%
def query_from_foursquare (query, lon, lat):
    
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lon}%2C{lat}&sort=DISTANCE&limit=3"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }

    response = requests.get(url, headers=headers).json()
    return response

# %%
def everything_from_foursquare (one_element, data):

    name = one_element["name"]
    lat = one_element["geocodes"]["main"]["latitude"]
    lon = one_element["geocodes"]["main"]["longitude"]
    distance = one_element["distance"]
    
    dict_ = {"name": name, "latitude": lat, "longitude": lon, "data": data, "distance": distance}
    
    return dict_

# %%
sf_lon= "37.7968917"
sf_lat= "-122.4032027"
airport_query="airport"
starbucks_query="Starbucks"
dog_groom_query="Dog grooming"
airport_category= "19040"
preschool_category="12056"
primaryschool_category="12057"
train_category="19046"
nightlife_category="10032"
vegan_category="13377"
basketball_category="18008"

# %%
response=category_from_foursquare(sf_lon, sf_lat, airport_category)

# %%
new_list = []
for i in response["results"]:
    new_list.append(everything_from_foursquare (i, "Airport"))

df = pd.DataFrame(new_list)
df_sanfrancisco = pd.concat([df_sanfrancisco, df])

# %%
response=category_from_foursquare(sf_lon, sf_lat, preschool_category)
new_list = []
for i in response["results"]:
    new_list.append(everything_from_foursquare (i, "Preschool"))

df = pd.DataFrame(new_list)
df_sanfrancisco = pd.concat([df_sanfrancisco, df])

# %%
response=category_from_foursquare(sf_lon, sf_lat, primaryschool_category)
new_list = []
for i in response["results"]:
    new_list.append(everything_from_foursquare (i, "Primary and Secondary School"))

df = pd.DataFrame(new_list)
df_sanfrancisco = pd.concat([df_sanfrancisco, df])

# %%
response=category_from_foursquare(sf_lon, sf_lat, train_category)
new_list = []
for i in response["results"]:
    new_list.append(everything_from_foursquare (i, "Train Station"))

df = pd.DataFrame(new_list)
df_sanfrancisco = pd.concat([df_sanfrancisco, df])

# %%
response=category_from_foursquare(sf_lon, sf_lat, nightlife_category)
new_list = []
for i in response["results"]:
    new_list.append(everything_from_foursquare (i, "Night Club"))

df = pd.DataFrame(new_list)
df_sanfrancisco = pd.concat([df_sanfrancisco, df])

# %%
response=category_from_foursquare(sf_lon, sf_lat, vegan_category)
new_list = []
for i in response["results"]:
    new_list.append(everything_from_foursquare (i, "Vegan Restaurant"))

df = pd.DataFrame(new_list)
df_sanfrancisco = pd.concat([df_sanfrancisco, df])

# %%
response=category_from_foursquare(sf_lon, sf_lat, basketball_category)
new_list = []
for i in response["results"]:
    new_list.append(everything_from_foursquare (i, "Basketball stadium"))

df = pd.DataFrame(new_list)
df_sanfrancisco = pd.concat([df_sanfrancisco, df])

# %%
response=query_from_foursquare (starbucks_query, sf_lon, sf_lat)
new_list = []
for i in response["results"]:
    new_list.append(everything_from_foursquare (i, "starbucks"))

df = pd.DataFrame(new_list)
df_sanfrancisco = pd.concat([df_sanfrancisco, df])

# %%
response=query_from_foursquare ( dog_groom_query,sf_lon, sf_lat)
new_list = []
for i in response["results"]:
    new_list.append(everything_from_foursquare (i, "dog grooming"))

df = pd.DataFrame(new_list)
df_sanfrancisco = pd.concat([df_sanfrancisco, df])
df_sanfrancisco
# Out:
#                                             name   latitude   longitude
# 0                                           Digg  37.764726 -122.394523  \
# 1                                            Wix  37.756720 -122.405070
# 2                                      99designs  37.795531 -122.400598
# 3                                         Minted  37.797435 -122.403175
# 4                                    Netbiscuits  37.755037 -122.426442
# 0            Oakland International Airport (OAK)  37.712395 -122.213323
# 1      San Francisco International Airport (SFO)  37.616581 -122.386689
# 0                           Imane's Wonderschool  37.780740 -122.407515
# 1                         Presidio Knolls School  37.773203 -122.413809
# 2                           Alta Plaza Preschool  37.790221 -122.437322
# 0                  Jean Parker Elementary School  37.797687 -122.411024
# 1                       New School San Francisco  37.800775 -122.415078
# ...

# %%
df_sanfrancisco.to_csv("../dataframes/df_sanfrancisco.csv", index=False)
df_newyork.to_csv("../dataframes/df_newyork.csv", index=False)
df_london.to_csv("../dataframes/df_london.csv", index=False)
